# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import datetime as dt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, SimpleRNN

from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score

# %%
data = pd.read_csv('/content/drive/MyDrive/Crypto/test_2/Bitcoin/BTC-USD.csv', date_parser = True)
data
# Out:
#             Date          Open          High           Low         Close  \
# 0     2019-11-30   7764.057129   7836.102051   7515.849609   7569.629883
# 1     2019-12-01   7571.616211   7571.616211   7291.341797   7424.292480
# 2     2019-12-02   7424.036133   7474.818848   7233.399414   7321.988281
# 3     2019-12-03   7323.975586   7418.858887   7229.356934   7320.145508
# 4     2019-12-04   7320.125000   7539.784668   7170.922852   7252.034668
# ...          ...           ...           ...           ...           ...
# 1092  2022-11-26  16521.576172  16666.863281  16416.228516  16464.281250
# 1093  2022-11-27  16463.882813  16594.406250  16437.025391  16444.626953
# 1094  2022-11-28  16440.222656  16482.933594  16054.530273  16217.322266
# 1095  2022-11-29  16217.639648  16522.257813  16139.396484  16444.982422
# 1096  2022-11-30  16445.476563  17190.937500  16445.476563  17168.566406
#
#          Adj Close       Volume
# 0      7569.629883  17158194786
# 1      7424.292480  18720708479
# 2      7321.988281  17082040706
# 3      7320.145508  14797485769
# 4      7252.034668  21664240918
# ...            ...          ...
# 1092  16464.281250  18000008764
# 1093  16444.626953  20443898509
# 1094  16217.322266  27743025156
# 1095  16444.982422  23581685468
# 1096  17168.566406  29523576583
#
# [1097 rows x 7 columns]

# %% [markdown]
# # **Data Pre-processing**

# %%
#Replace None or Null values with forward filling technique using fillna function.

data = data.fillna(method = 'ffill')

# %%
#Convert Date column into Datatime format

data['Date'] = pd.to_datetime(data.Date)

# %% [markdown]
# # **Data Visualization**

# %%
# Visualize the close price history
plt.figure(figsize=(16, 8))
plt.plot(data['Date'], data['Close'], color="green")
plt.title('Bitcoin Close Price')
plt.xlabel("Time", fontsize=14,)
plt.ylabel("USDT", fontsize=14)
plt.show()

# %% [markdown]
# # **Data Spliting**

# %%
data_training = data[data['Date']< '2022-03-30'].copy()
data_training
# Out:
#           Date          Open          High           Low         Close  \
# 0   2019-11-30   7764.057129   7836.102051   7515.849609   7569.629883
# 1   2019-12-01   7571.616211   7571.616211   7291.341797   7424.292480
# 2   2019-12-02   7424.036133   7474.818848   7233.399414   7321.988281
# 3   2019-12-03   7323.975586   7418.858887   7229.356934   7320.145508
# 4   2019-12-04   7320.125000   7539.784668   7170.922852   7252.034668
# ..         ...           ...           ...           ...           ...
# 846 2022-03-25  43964.546875  44999.492188  43706.285156  44348.730469
# 847 2022-03-26  44349.859375  44735.996094  44166.273438  44500.828125
# 848 2022-03-27  44505.355469  46827.546875  44437.292969  46820.492188
# 849 2022-03-28  46821.851563  48086.835938  46690.203125  47128.003906
# 850 2022-03-29  47100.437500  48022.289063  47100.437500  47465.730469
#
#         Adj Close       Volume
# 0     7569.629883  17158194786
# 1     7424.292480  18720708479
# 2     7321.988281  17082040706
# 3     7320.145508  14797485769
# 4     7252.034668  21664240918
# ..            ...          ...
# 846  44348.730469  30574413034
# 847  44500.828125  16950455995
# 848  46820.492188  28160889722
# 849  47128.003906  36362175703
# 850  47465.730469  31397059069
#
# [851 rows x 7 columns]

# %%
data_test = data[data['Date']> '2022-03-30'].copy()
data_test
# Out:
#            Date          Open          High           Low         Close  \
# 852  2022-03-31  47062.148438  47512.027344  45390.539063  45538.675781
# 853  2022-04-01  45554.164063  46616.242188  44403.140625  46281.644531
# 854  2022-04-02  46285.500000  47028.281250  45782.511719  45868.949219
# 855  2022-04-03  45859.128906  47313.476563  45634.105469  46453.566406
# 856  2022-04-04  46445.273438  46791.089844  45235.816406  46622.675781
# ...         ...           ...           ...           ...           ...
# 1092 2022-11-26  16521.576172  16666.863281  16416.228516  16464.281250
# 1093 2022-11-27  16463.882813  16594.406250  16437.025391  16444.626953
# 1094 2022-11-28  16440.222656  16482.933594  16054.530273  16217.322266
# 1095 2022-11-29  16217.639648  16522.257813  16139.396484  16444.982422
# 1096 2022-11-30  16445.476563  17190.937500  16445.476563  17168.566406
#
#          Adj Close       Volume
# 852   45538.675781  33327427106
# 853   46281.644531  38162644287
# 854   45868.949219  29336594194
# 855   46453.566406  25414397610
# 856   46622.675781  32499785455
# ...            ...          ...
# 1092  16464.281250  18000008764
# 1093  16444.626953  20443898509
# 1094  16217.322266  27743025156
# 1095  16444.982422  23581685468
# 1096  17168.566406  29523576583
#
# [245 rows x 7 columns]

# %% [markdown]
# # **Feature Engineering**

# %%
#feature selection
training_data = data_training.drop(['Date', 'Adj Close'], axis = 1)
training_data.head()
# Out:
#           Open         High          Low        Close       Volume
# 0  7764.057129  7836.102051  7515.849609  7569.629883  17158194786
# 1  7571.616211  7571.616211  7291.341797  7424.292480  18720708479
# 2  7424.036133  7474.818848  7233.399414  7321.988281  17082040706
# 3  7323.975586  7418.858887  7229.356934  7320.145508  14797485769
# 4  7320.125000  7539.784668  7170.922852  7252.034668  21664240918

# %%
#Normalizing training_data
scaler = MinMaxScaler()
training_data = scaler.fit_transform(training_data)
training_data
# Out:
# array([[0.04415035, 0.03946352, 0.05473889, 0.04151767, 0.01448294],
#        [0.04107362, 0.03529562, 0.05113379, 0.03919584, 0.019096  ],
#        [0.03871412, 0.03377024, 0.05020336, 0.03756148, 0.01425811],
#        ...,
#        [0.63156792, 0.65391045, 0.64761556, 0.66856792, 0.04696654],
#        [0.66860391, 0.67375497, 0.68379231, 0.67348056, 0.07117946],
#        [0.67305793, 0.67273781, 0.69037977, 0.67887589, 0.05652079]])

# %%
#Prepare train data
X_train = []
Y_train = []

# %%
training_data.shape[0]
# Out:
# 851

# %%
for i in range(60, training_data.shape[0]):
    X_train.append(training_data[i-60:i])
    Y_train.append(training_data[i,0])

# %%
X_train, Y_train = np.array(X_train), np.array(Y_train)
X_train.shape
# Out:
# (791, 60, 5)

# %% [markdown]
# # Model Building

# %%
model = Sequential()
# model.add(LSTM(units = 50, activation = 'relu', return_sequences = True, input_shape = (X_train.shape[1], 5)))
# model.add(Dropout(0.2))

# model.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
# model.add(Dropout(0.3))

# model.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
# model.add(Dropout(0.4))

# model.add(LSTM(units = 120, activation = 'relu'))
# model.add(Dropout(0.5))

# model.add(Dense(units =1))



model.add(SimpleRNN(128,activation="relu",return_sequences=True, input_shape=(X_train.shape[1], 5)))
model.add(Dropout(0.25))

model.add(SimpleRNN(128,activation="relu",return_sequences=True))
model.add(Dropout(0.25))

model.add(SimpleRNN(128,activation="relu",return_sequences=False))
model.add(Dropout(0.25))

model.add(Dense(1))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 60, 128)           17152
#
#  dropout (Dropout)           (None, 60, 128)           0
#
#  simple_rnn_1 (SimpleRNN)    (None, 60, 128)           32896
#
#  dropout_1 (Dropout)         (None, 60, 128)           0
#
#  simple_rnn_2 (SimpleRNN)    (None, 128)               32896
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 83,073
# Trainable params: 83,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
history = model.fit(X_train, Y_train, epochs = 50, batch_size =32)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 4s 73ms/step - loss: 0.0663
# Epoch 2/50
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0124
# Epoch 3/50
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0095
# Epoch 4/50
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0090
# Epoch 5/50
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0068
# Epoch 6/50
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0057
# Epoch 7/50
# 25/25 [==============================] - 2s 73ms/step - loss: 0.0059
# Epoch 8/50
# 25/25 [==============================] - 2s 73ms/step - loss: 0.0054
# Epoch 9/50
# 25/25 [==============================] - 2s 70ms/step - loss: 0.0050
# Epoch 10/50
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0049
# Epoch 11/50
# 25/25 [==============================] - 2s 73ms/step - loss: 0.0043
# Epoch 12/50
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0048
# Epoch 13/50
# 25/25 [==============================] - 2s 71ms/step - loss: 0.0054
# Epoch 14/50
# 25/25 [==============================] - 2s 71ms/step - loss: 0.0049
# Epoch 15/50
# 25/25 [==============================] - 2s 73ms/step - loss: 0.0040
# Epoch 16/50
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0039
# Epoch 17/50
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0045
# Epoch 18/50
# 25/25 [==============================] - 2s 73ms/step - loss: 0.0048
# Epoch 19/50
# 25/25 [==============================] - 2s 73ms/step - loss: 0.0033
# Epoch 20/50
# 25/25 [==============================] - 2s 73ms/step - loss: 0.0034
# Epoch 21/50
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0051
# Epoch 22/50
# 25/25 [==============================] - 2s 73ms/step - loss: 0.0038
# Epoch 23/50
# 25/25 [==============================] - 2s 73ms/step - loss: 0.0040
# Epoch 24/50
# 25/25 [==============================] - 2s 73ms/step - loss: 0.0035
# Epoch 25/50
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0038
# Epoch 26/50
# 25/25 [==============================] - 2s 71ms/step - loss: 0.0029
# Epoch 27/50
# 25/25 [==============================] - 2s 73ms/step - loss: 0.0029
# Epoch 28/50
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0027
# Epoch 29/50
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0029
# Epoch 30/50
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0034
# Epoch 31/50
# 25/25 [==============================] - 2s 73ms/step - loss: 0.0042
# Epoch 32/50
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0033
# Epoch 33/50
# 25/25 [==============================] - 2s 71ms/step - loss: 0.0031
# Epoch 34/50
# 25/25 [==============================] - 2s 71ms/step - loss: 0.0029
# Epoch 35/50
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0035
# Epoch 36/50
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0043
# Epoch 37/50
# 25/25 [==============================] - 2s 71ms/step - loss: 0.0030
# Epoch 38/50
# 25/25 [==============================] - 2s 71ms/step - loss: 0.0030
# Epoch 39/50
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0029
# Epoch 40/50
# 25/25 [==============================] - 2s 71ms/step - loss: 0.0027
# Epoch 41/50
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0025
# Epoch 42/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.0022
# Epoch 43/50
# 25/25 [==============================] - 2s 71ms/step - loss: 0.0026
# Epoch 44/50
# 25/25 [==============================] - 2s 71ms/step - loss: 0.0025
# Epoch 45/50
# 25/25 [==============================] - 2s 69ms/step - loss: 0.0025
# Epoch 46/50
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0027
# Epoch 47/50
# 25/25 [==============================] - 2s 71ms/step - loss: 0.0032
# Epoch 48/50
# 25/25 [==============================] - 2s 71ms/step - loss: 0.0027
# Epoch 49/50
# 25/25 [==============================] - 2s 70ms/step - loss: 0.0022
# Epoch 50/50
# 25/25 [==============================] - 2s 69ms/step - loss: 0.0031

# %%
loss = history.history['loss']

epochs = range(len(loss))

plt.plot(epochs, loss, 'r', label='Training loss')
plt.title('Training loss')
plt.legend(loc=0)
plt.figure()

plt.show()

# %% [markdown]
# # **Performance Evaluation**

# %%
past_60_days = data_training.tail(60)
df= past_60_days.append(data_test, ignore_index = True)
df = df.drop(['Date', 'Adj Close'], axis = 1)
df.head()
# Out:
#            Open          High           Low         Close       Volume
# 0  37780.714844  38576.261719  37406.472656  38138.179688  17194183075
# 1  38151.917969  38266.339844  37437.710938  37917.601563  14643548444
# 2  37920.281250  38647.261719  36733.574219  38483.125000  20734730465
# 3  38481.765625  39115.132813  38113.664063  38743.273438  20288500328
# 4  38743.714844  38834.617188  36832.730469  36952.984375  19155189416

# %%
inputs = scaler.transform(df)
inputs
# Out:
# array([[0.52405479, 0.52388252, 0.53471615, 0.52986405, 0.01458919],
#        [0.52998956, 0.51899862, 0.53521777, 0.52634022, 0.00705887],
#        [0.52628617, 0.52500138, 0.52391089, 0.53537471, 0.02504206],
#        ...,
#        [0.18286434, 0.17572467, 0.1918512 , 0.17966846, 0.04573287],
#        [0.1793057 , 0.17634436, 0.19321397, 0.18330543, 0.03344721],
#        [0.18294834, 0.18688176, 0.19812894, 0.19486502, 0.05098965]])

# %%
X_test = []
Y_test = []
for i in range (60, inputs.shape[0]):
    X_test.append(inputs[i-60:i])
    Y_test.append(inputs[i, 0])

# %%
X_test, Y_test = np.array(X_test), np.array(Y_test)
X_test.shape, Y_test.shape
# Out:
# ((245, 60, 5), (245,))

# %%
Y_pred = model.predict(X_test)
# Out:
# 8/8 [==============================] - 0s 16ms/step

# %%
print("RMSE: ", math.sqrt(mean_squared_error(Y_test,Y_pred)))
print("MSE: ", mean_squared_error(Y_test,Y_pred))
print("MAE: ", mean_absolute_error(Y_test,Y_pred))
print("R2 score:", r2_score(Y_test, Y_pred))
# Out:
# RMSE:  0.03540275367828391
# MSE:  0.001253354968005245
# MAE:  0.024443324585581273
# R2 score: 0.9234606481195785

# %%
scaler.scale_
# Out:
# array([1.59879371e-05, 1.57585063e-05, 1.60577871e-05, 1.59754515e-05,
#        2.95233159e-12])

# %%
scale = 1/5.18164146e-05
scale
# Out:
# 19298.903787912797

# %%
Y_test = Y_test*scale
Y_pred = Y_pred*scale

# %%
# Y_test = scaler.inverse_transform(Y_test)
# Y_pred = scaler.inverse_transform(Y_pred)

# %%
plt.figure(figsize=(14,5))
plt.plot(Y_test, color = 'red', label = 'Actual Bitcoin Price')
plt.plot(Y_pred, color = 'green', label = 'Predicted Bitcoin Price')
plt.title('Bitcoin Price Prediction using RNN')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
